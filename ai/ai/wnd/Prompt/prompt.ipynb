# %%
# JS 模块化
# 浏览器的副产品 2015 es6+
# import openai from OpenAI
from openai import OpenAI
# go里面没有class ，也不需要new
client = OpenAI(
    api_key="",
    # 转发请求
    base_url="https://api.deepseek.com/v1",
    
)
# 参数默认值
 # 工具函数
# 主要用deepseek-chat 不传
# 传入 其它模型
# llm 很智能
# - completions aigc 生成
# - chat  聊天+completions  生成接口 对话形式
def get_completion(prompt, model="deepseek-chat"):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content  

print(get_completion("何为vibe coding"))
# get_completion("",'gpt-5')
# Out:
# 这是一个非常有趣且前沿的概念。我来为你详细解释一下“Vibe Coding”。
#
# ### 核心定义
#
# **Vibe Coding** 是一种全新的编程方式，简单来说就是：**完全依赖人工智能（特别是大语言模型，如ChatGPT、Claude、Gemini等）来编写代码，而人类开发者只负责提出想法、描述需求、进行审阅和决策。**
#
# 你可以把它理解为“意念编程”或“氛围编程”——你不需要亲手敲击键盘写代码，只需要用自然语言描述你想要的功能，AI就会自动生成。你的角色从“程序员”变成了“产品经理”或“创意总监”。
#
# ### 核心特征
#
# 1.  **描述，而非编码**：你不再需要掌握具体的编程语法、框架或API。你只需要说出你想要什么，例如：“帮我写一个能记录每日水量的网页应用，界面要简洁、现代”。
# 2.  **全面依赖AI**：AI不仅仅是辅助工具，而是实际代码的主要产出者。你可能是在对话界面中（如ChatGPT、Claude）输入需求，也可能是在一个集成了AI的IDE（如Cursor、GitHub Copilot的聊天功能）中操作。
# 3.  **快速原型与迭代**：你可以说“这页字体太小了，改成20px”，AI会立刻为你修改。整个开发流程从“写代码 -> 运行 -> 调试”变成了“提需求 -> 看结果 -> 微调需求”，速度极快。
# 4.  **模糊的技术边界**：你不需要了解底层的技术栈。你可以说“用Python写个后端，但输出HTML界面”，即使这种组合不常见，AI也会尝试去实现。你只需关注最终效果。
#
# ### “Vibe Coding”这个说法从何而来？
#
# 这个词是由著名的人工智能研究者、前OpenAI和Tesla的AI总监 **Andrej Karpathy** 在2025年初提出的。他在一次演讲或博客中提到，他发现自己越来越多地采用这种方式编程：完全沉浸在AI生成的代码流中，很少去手动修改代码，几乎只是接受AI的全部建议。他将这种几乎“不费脑筋”、完全跟着感觉走的编程状态称为 **“Vibe Coding”**。
#
# ### Vibe Coding的典型工作流程（对比传统方式）
#
# | 步骤 | 传统编程 | Vibe Coding |
# | :--- | :--- | :--- |
# | **1. 想法** | 我想要一个个人博客。 | 我想要一个超酷的个人博客。 |
# | **2. 设计** | 画线框图、设计数据库、写技术方案。 | 描述功能：有文章列表、分类、搜索功能、深色模式。 |
# | **3. 编码** | 在编辑器中手动敲入HTML、CSS、JavaScript/Python代码，逐行调试。 | 将上述描述输入给AI（如“用HTML/CSS/JS写一个单页应用……”）。 |
# | **4. 调试** | 读错误日志，手动查找bug，修复。 | 描述错误：“提交表单后页面没反应”，AI帮你检查和修复。 |
# | **5. 迭代** | 修改代码，重构，考虑最佳实践。 | 继续提需求：“在深色模式下，文字颜色太暗了，调亮一点。” |
#
# ### Vibe Coding的优势与局限
#
# **优势：**
#
# -   **门槛极低**：不懂编程的人也能快速构建出原型或小工具。
# -   **速度极快**：开发效率提升数倍甚至数十倍，非常适合快速验证想法（MVP）。
# -   **解放创造力**：将开发者从繁琐的语法和调试中解放出来，更专注于创意和产品逻辑。
#
# **局限与风险：**
#
# 1.  **理解不深，难以调试复杂问题**：当AI生成的代码出现深层逻辑错误或性能瓶颈时，如果你不懂编程，将完全无法排查和修复。你只能盲目地重复告诉AI“修好它”，效果往往不好。
# 2.  **安全与可靠性问题**：AI可能会生成存在安全漏洞（如SQL注入）、逻辑缺陷或严重性能问题的代码。没有专业知识的“审核者”很难发现这些问题。
# 3.  **“黑箱”问题**：你不知道AI生成的代码具体是如何工作的。一旦出现问题或需要定制，你将无从下手。
# 4.  **对于复杂项目力不从心**：对于大型、需要严格架构设计、高并发、微服务等复杂系统，Vibe Coding几乎不可能胜任。AI无法理解项目全局的架构设计、模块间的复杂依赖关系和长期演进的需求。
# 5.  **代码质量与维护性**：AI生成的代码可能风格不一、缺乏注释、不符合团队规范，导致长期维护困难。
#
# ### 结论：Vibe Coding是未来吗？
#
# **Vibe Coding 不是一个全面的替代方案，而是一种强大的新范式。**
#
# -   **对于非程序员**：它意味着一个全新的“软件创造”时代。你可以快速为自己或小团队构建出非常实用的工具、网页或自动化脚本，实现“编程民主化”。
# -   **对于专业程序员**：它是一种“超级放大器”。专业程序员可以利用Vibe Coding快速完成原型搭建、编写测试用例、处理重复性劳动，从而将精力集中在系统架构、核心算法、复杂逻辑和代码审阅上。**Vibe Coding让优秀的程序员变得更高效，而不是让不懂编程的人直接变成架构师。**
#
# **一句话总结：Vibe Coding 是一种通过自然语言指令让AI为你写代码的编程体验，它极大地降低了编程门槛并提升了开发效率，但目前更适合用于快速原型验证和解决简单到中等复杂度的任务，而无法完全替代人类对于复杂系统设计、安全性审查和深度调试的专业能力。**

# %%
# python 多行字符串模板
text = f"""
你应当通过尽可能清晰、具体的指令，来明确你希望模型完成的任务。
这能引导模型产出符合预期的结果，同时降低回复内容偏离主题或出现错误的概率。
不要把编写清晰的提示词和精简提示词混为一谈。
很多时候，篇幅更长的提示词能为模型提供更完整的说明与背景信息，进而让输出内容更加详实、贴合需求。
"""
# 字符串模板
prompt = f"""
将三个反引号之间的文本总结为一句话。
```{text}```
"""
prompt
# Out:
# '\n将三个反引号之间的文本总结为一句话。\n```\n你应当通过尽可能清晰、具体的指令，来明确你希望模型完成的任务。\n这能引导模型产出符合预期的结果，同时降低回复内容偏离主题或出现错误的概率。\n不要把编写清晰的提示词和精简提示词混为一谈。\n很多时候，篇幅更长的提示词能为模型提供更完整的说明与背景信息，进而让输出内容更加详实、贴合需求。\n```\n'

# %%
print(get_completion(prompt))
# Out:
# 清晰的指令能引导模型产出符合预期的结果，而更长的提示词往往比精简的提示词更能提供完整背景，提升输出质量。

# %%
prompt =f"""
请列出四大名著，并标注对应的作者于书籍类型
使用JSON格式呈现，需包含一下字段:
book_id(书籍编号)、title(书名)、author(作者)、genres(书籍类型)、desc(概述)。
"""
print(get_completion(prompt))
# Out:
# ```json
# [
#     {
#         "book_id": 1,
#         "title": "三国演义",
#         "author": "罗贯中",
#         "genres": "历史演义小说",
#         "desc": "以东汉末年至西晋统一为背景，描写魏、蜀、吴三国之间的政治、军事斗争，塑造了曹操、诸葛亮、关羽等众多经典人物形象，是中国第一部长篇章回体历史小说。"
#     },
#     {
#         "book_id": 2,
#         "title": "西游记",
#         "author": "吴承恩",
#         "genres": "神魔小说",
#         "desc": "讲述唐僧师徒四人（孙悟空、猪八戒、沙僧）前往西天取经，历经九九八十一难，降妖除魔的故事，充满奇幻色彩与幽默讽刺，是中国古代神魔小说的代表作。"
#     },
#     {
#         "book_id": 3,
#         "title": "水浒传",
#         "author": "施耐庵",
#         "genres": "英雄传奇小说",
#         "desc": "以北宋末年宋江起义为蓝本，描写108位好汉在梁山泊聚义，反抗官府压迫，后接受招安并参与征讨的故事，展现了官逼民反的主题与江湖义气。"
#     },
#     {
#         "book_id": 4,
#         "title": "红楼梦",
#         "author": "曹雪芹（前80回）、高鹗（后40回续写）",
#         "genres": "世情小说",
#         "desc": "以贾、史、王、薛四大家族的兴衰为背景，通过贾宝玉、林黛玉、薛宝钗的爱情悲剧，深刻揭示了封建社会的腐朽与人性复杂，被誉为中国古典文学的巅峰之作。"
#     }
# ]
# ```

# %%
# 一步一步，分步执行，有利于任务的顺序执行
# 用户的输入
# 具身智能
text = f"""
泡一杯茶其实很简单！
首先把水烧开。烧水的同时，拿出茶杯，放入茶包。
水烧开后，将热水冲入杯中浸泡茶包。静置片刻让茶香析出。
几分钟后取出茶包。
根据个人口味，还可以加入糖或牛奶。
这样一杯美味的茶饮就泡好了。
"""
# 转义 符号本身
prompt = f"""
你将收到由三个引号包裹的文本。
若文本中包含一系列操作指令，
请按照以下格式重新整理这些指令。
步骤一···
步骤二···
步骤三···
···
步骤 N ···

如果文本中没有一系列操作指引，
直接输出**没有必要的步骤**
\"\"\"{text}\"\"\"
"""
print(get_completion(prompt))
# Out:
# 步骤一：把水烧开。
# 步骤二：烧水的同时，拿出茶杯，放入茶包。
# 步骤三：水烧开后，将热水冲入杯中浸泡茶包。
# 步骤四：静置片刻让茶香析出。
# 步骤五：几分钟后取出茶包。
# 步骤六：根据个人口味，加入糖或牛奶。

# %%
text = f"""
今日阳光明媚，鸟儿欢唱。这样的好天气很适合去公园散步。
花儿竞相绽放，树木在微风中轻轻摇曳。
人们纷纷出门，享受这宜人的天气。
有人野餐，有人嬉戏，还有人悠闲地躺在草地上休憩。
这是亲近户外、领略自然之美的绝佳时刻。
"""
prompt = f"""
你将收到由三个引号包裹的文本。
若文本中包含一系列操作指令，
请按照以下格式重新整理这些指令。
步骤一···
步骤二···
步骤三···
···
步骤 N ···

如果文本中没有一系列操作指引，
直接输出**没有必要的步骤**
\"\"\"{text}\"\"\"
"""
print(get_completion(prompt))
# Out:
# 没有必要的步骤

# %%
# Few-shots  例子
prompt = f"""
你的任务是保持统一的行文风格作答。
提问：请讲讲何为耐心。
回答：能凿出幽深峡谷的江河，源自涓涓细流；
恢弘壮阔的交响乐，起于单个音符；
精美繁复的织锦，始于一丝线。
提问：请讲讲何为韧性？
"""
print(get_completion(prompt))
# Out:
# 能在锻锤下愈发锋利的刀刃，源于百折不断；
# 暴风雪中挺立的松枝，生于盘根错节；
# 断崖上重生的枝桠，长于不弃寸土。

# %%
text = f"""
在一座风光宜人的小村庄里，姐弟俩杰克和吉尔动身前往山顶的水井取水。
两人一路欢歌向上攀登，不料意外突生 
—— 杰克被石头绊倒，滚下山坡，吉尔也跟着摔了下去。
二人虽受了些轻伤，还是回到了家中，得到家人温柔的安抚。
这场小意外并未磨灭他们冒险的兴致，此后他们依旧满心欢喜地四处游玩。
"""
# nlp 任务 翻译任务
prompt = f"""
执行以下操作：
将三个反引号内的文本概括为一句话。
把这句话摘要翻译成法语。
列出法语摘要中出现的所有人名。
使用JSON格式呈现，包含字段：french_summary(法语摘要)、
num_names(人物数量)、names(人物名字,用&链接)。
答案分行展示。

Text: 
```{text}```
"""
print(get_completion(prompt))
# Out:
# 法语摘要：Dans un charmant petit village, les frères et sœurs Jack et Jill montent vers un puits au sommet d'une colline, mais ils tombent accidentellement et rentrent chez eux légèrement blessés.
#
# 人物数量：2
# 人物名字：Jack & Jill
#
# ```json
# {
#   "french_summary": "Dans un charmant petit village, les frères et sœurs Jack et Jill montent vers un puits au sommet d'une colline, mais ils tombent accidentellement et rentrent chez eux légèrement blessés.",
#   "num_names": 2,
#   "names": "Jack & Jill"
# }
# ```

# %%
prompt = f"""
介绍一下蜜雪冰城品牌的滑雪装备
"""
print(get_completion(prompt))
# Out:
# 这是一个非常有趣的问题！首先要明确一个核心事实：**蜜雪冰城品牌目前并没有正式推出过任何滑雪装备产品。**
#
# 你听到或看到的“蜜雪冰城滑雪装备”，通常源于以下几种情况：
#
# 1.  **品牌跨界营销（非卖品）**：蜜雪冰城曾推出过一些滑雪主题的周边产品，比如**滑雪板、雪镜、手套**等，但这些通常是作为抽奖奖品、联名限定赠品或粉丝活动福利，**并不在门店或官方商城公开售卖**。例如，2023-2024雪季期间，蜜雪冰城与一些滑雪场或潮流品牌有过合作，发布过印有雪王形象的单板或双板图案的周边。
# 2.  **网友恶搞或二创设计**：网络上流传的“蜜雪冰城滑雪服”、“雪王滑雪板”等图片或视频，很多是网友用AI生成的创意设计，或是幽默的PS作品，并不是官方真实产品。
# 3.  **玩梗与文化符号**：蜜雪冰城的吉祥物“雪王”本身就是冰雪主题，与滑雪运动在视觉上契合。因此，粉丝们会自发地将“雪王”与滑雪装备联系在一起，形成一种亚文化梗。
#
# ---
#
# **如果假设蜜雪冰城真的出了一套滑雪装备（纯属虚构或推测），它可能会是什么风格？**
#
# 基于品牌调性（极致性价比、亲民、快乐），可以合理脑补：
#
# -   **设计元素**：通体白色为主，印有巨大的雪王Logo或“蜜雪冰城”字样，雪镜可能是柠檬黄色，板底可能是红色。图案可能会是雪王举着冰淇淋滑雪的卡通形象。
# -   **材质与性能**：大概率采用入门级面料（如普通防水尼龙），保暖层可能是普通抓绒，防风防水指数不会太高。板类可能使用复合材料，工艺基础。目的是满足**新手体验或拍照好看**的需求。
# -   **定价**：这会是最大特色。假设真的推出，极有可能遵循“极致性价比”路线。一套新手雪服可能定价在**200-400元**（对比主流品牌动辄1000+），雪板可能在**600-1000元**（对比专业板3000+）。这个价位会比市面最便宜的迪卡侬还要更低，主打一个“让所有想尝试滑雪的人都能买得起”。
# -   **购买场景**：可能不会进雪具店，而是通过**蜜雪冰城的小程序、会员积分商城**，或者以**买奶茶加钱换购**的形式出现（比如“+49元获得雪王雪镜挂件”）。
#
# ---
#
# **结论与建议：**
#
# -   **目前你想买真正的蜜雪冰城滑雪装备**：**买不到**。不要相信任何非官方渠道的销售信息，它们大概率是盗版或虚假宣传。
# -   **如果你想体验“蜜雪冰城式”的滑雪入门装备**：可以关注**迪卡侬**的入门线（价格亲民、品质够用），或者关注**国产品牌**如**南恩、Vector**等，它们的设计和性价比与“蜜雪精神”很接近。
# -   **如果你是玩梗或收藏**：可以留意官方微博、小红书偶尔发布的**抽奖活动**，或者等待下一次联名。
#
# 总结：蜜雪冰城的滑雪装备目前只是一个“网络传说”和“品牌梗”，但它确实反映了年轻人对“平价快乐”与“小众爱好”结合的美好想象。如果真的有一天卖，雪王大概率会踩着板子给你递上一杯热奶茶。
